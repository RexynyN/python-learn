# %% [markdown]
# https://ri.bb.com.br/informacoes-financeiras/central-de-resultados/
#
# https://ri.unipar.com/mercado-de-capitais/dividendos-e-bonificacoes/
#
# https://www.santander.com.br/ri/dividendos
#
# https://ri.klabin.com.br/dividendos-e-jcp/
#
# https://ri.taesa.com.br/informacoes-financeiras/dividendos/
#
# https://ri.cemig.com.br/

# %%
import pandas as pd

df = pd.read_excel('bb.xlsx', sheet_name='Dividendos JCP')

df
# Out:
#                                        Índice        1T06        2T06
# 0                               União Federal  675.999082  438.174407  \
# 1                                       Previ  129.951295   70.745447
# 2                                       BNDES   53.873939   17.686525
# 3                                          PF   23.574808   27.689062
# 4                                          PJ    9.809988   22.036183
# 5                         Capital Estrangeiro   30.844829   42.071583
# 6                            Incorporação BNC           0           0
# 7                                       TOTAL  924.053941  618.403207
# 8                                         NaN         NaN         NaN
# 9                                         NaN      Mar/06      Jun/06
# 10  Dividendos e JCP / Ação - Acionistas (R$)    1.172273      0.7493
# 11                  Dividend yield (%) 12M ¹     2.112203    1.499189
#
# ...
